# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from uncertainties import ufloat
from uncertainties import unumpy
from lmfit.models import GaussianModel,LinearModel

# %% [markdown]
# Espectros

# %%
fondo=pd.read_csv("./data/2021-12-15_fon_24h.csv")
calibracion=pd.read_csv("./data/2021-11-15_cal_133Ba22Na137Cs60Co_600s_1.csv")
canales=fondo.canal
suelo=pd.read_csv("./data/2021-12-04_mue_DG-EG-014_24h.csv")
th=pd.read_csv("./data/2021-11-15_mue_IAEA-RGTh-1_24h.csv")
u=pd.read_csv("./data/2021-11-16_mue_IAEA-RGU-1_24h.csv")
k=pd.read_csv("./data/2021-11-17_mue_IAEA-RGK-1_24h.csv")


suelo_I=suelo.I_gamma-fondo.I_gamma
th_I=th.I_gamma-fondo.I_gamma
u_I=u.I_gamma-fondo.I_gamma
k_I=k.I_gamma-fondo.I_gamma
calibracion_I=calibracion.I_gamma-fondo.I_gamma

# %%
def ajuste(data,x1,x2):
    gaussiana=GaussianModel()
    fondo=LinearModel()
    ajuste=gaussiana+fondo
    x=data.canal[x1:x2].values
    y=data.I_gamma[x1:x2].values
    parametros=gaussiana.guess(data=y,x=x)
    parametros+=fondo.guess(data=y,x=x)
    fit=ajuste.fit(y,parametros,x=x)
    return fit

# %% [markdown]
# # Ajuste energía

# %%
limites=[[2400,2480],[2635,2670],[2750,2800],[1350,1415],[720,770],[610,650]]
Energias_calibracion=[1173.22,1274.53,1332.49,661.65,356.013,302.851]
mu=[]
for x1,x2 in limites:
    fit=ajuste(calibracion,x1,x2)
    params=fit.params
    mu.append(params["center"].value)  
Tabla_calibracion=pd.DataFrame()
Tabla_calibracion["E"]=Energias_calibracion
Tabla_calibracion["mu"]=mu

# %%
y=Tabla_calibracion.E
x=Tabla_calibracion.mu
recta=LinearModel()
params=recta.guess(y,x=x)
recta=recta.fit(y,params,x=x)
E=recta.eval(x=canales)
print(recta.uvars)

def canal(E):
    return(E-recta.params["intercept"].value)/recta.params["slope"].value
# Out:
# {'slope': 0.4809916259041778+/-4.5505519070550416e-05, 'intercept': -1.1230228733145635+/-0.09011859015040846}

# %%
def I(sigma,M):
    return np.sqrt(2*np.pi)*sigma*M



def ajusteE(data,x1,x2):
    gaussiana=GaussianModel()
    fondo=LinearModel()
    ajuste=gaussiana+fondo
    x1=round(canal(x1))
    x2=round(canal(x2))
    y=data[x1:x2].values
    x=E[x1:x2]    
    parametros=gaussiana.guess(data=y,x=x)
    parametros+=fondo.guess(data=y,x=x)
    fit=ajuste.fit(y,parametros,x=x)
    return fit

# %% [markdown]
# # ajuste K

# %% [markdown]
# referencia

# %%
plt.plot(E,k_I)
fit=ajusteE(k_I,1450,1470)
fit.params
plt.plot(np.linspace(1450,1470,100),fit.eval(x=np.linspace(1450,1470,100)))
plt.xlim(1449,1470)

print(f"I={I(fit.uvars['sigma']/recta.params['slope'],fit.uvars['height']):.1uS}")
fit.params
print(fit.uvars["sigma"])
# Out:
# I=2.82(2)e+05
# 1.423+/-0.012

# %% [markdown]
# muestra

# %%
plt.plot(E,suelo_I,ds="steps-mid")
fit=ajusteE(suelo_I,1450,1470)
fit.params['sigma'].set(value=1.4229)
plt.plot(np.linspace(1450,1470,100),fit.eval(x=np.linspace(1450,1470,100)))
plt.xlim(1450,1470)
plt.ylim(0,250)
print(f"I={I(fit.uvars['sigma']/recta.params['slope'],fit.uvars['height']):.1uS}")
fit.params
# Out:
# I=4.9(7)e+02
# Parameters([('amplitude', <Parameter 'amplitude', value=236.44927617863658 +/- 32.3, bounds=[-inf:inf]>), ('center', <Parameter 'center', value=1459.950933960588 +/- 0.156, bounds=[-inf:inf]>), ('sigma', <Parameter 'sigma', value=1.4229 +/- 0.166, bounds=[0.0:inf]>), ('fwhm', <Parameter 'fwhm', value=3.350673378 +/- 0.392, bounds=[-inf:inf], expr='2.3548200*sigma'>), ('height', <Parameter 'height', value=66.29391951088655 +/- 9.23, bounds=[-inf:inf], expr='0.3989423*amplitude/max(1e-15, sigma)'>), ('slope', <Parameter 'slope', value=0.8498242707821738 +/- 0.41, bounds=[-inf:inf]>), ('intercept', <Parameter 'intercept', value=-1121.7107370337908 +/- 599, bounds=[-inf:inf]>)])

# %% [markdown]
# # Ajuste U

# %% [markdown]
# referencia

# %%
plt.plot(E,u_I)
fit=ajusteE(u_I,340,365)
fit.params
plt.plot(np.linspace(340,365,100),fit.eval(x=np.linspace(340,365,100)))
plt.xlim(340,365)

print(f"I={I(fit.uvars['sigma']/recta.params['slope'],fit.uvars['height']):.1uS}")
fit.params
# Out:
# I=8.6(1)e+05
# Parameters([('amplitude', <Parameter 'amplitude', value=411305.1778903329 +/- 6.39e+03, bounds=[-inf:inf]>), ('center', <Parameter 'center', value=351.86400157989664 +/- 0.0264, bounds=[-inf:inf]>), ('sigma', <Parameter 'sigma', value=1.8616551920858027 +/- 0.0287, bounds=[0.0:inf]>), ('fwhm', <Parameter 'fwhm', value=4.38386287942749 +/- 0.0675, bounds=[-inf:inf], expr='2.3548200*sigma'>), ('height', <Parameter 'height', value=88140.40020248598 +/- 1.1e+03, bounds=[-inf:inf], expr='0.3989423*amplitude/max(1e-15, sigma)'>), ('slope', <Parameter 'slope', value=-26.833157327954865 +/- 44.5, bounds=[-inf:inf]>), ('intercept', <Parameter 'intercept', value=15172.261312526462 +/- 1.57e+04, bounds=[-inf:inf]>)])

# %% [markdown]
# muestra

# %%
plt.plot(E,suelo_I)
fi2t=ajusteE(suelo_I,340,365)
fi2t.params
plt.plot(np.linspace(340,365,100),fi2t.eval(x=np.linspace(340,365,100)))
plt.xlim(340,365)

print(f"I={I(fi2t.uvars['sigma']/recta.params['slope'],fi2t.uvars['height']):.1uS}")
fi2t.params
# Out:
# I=1.57(2)e+05
# Parameters([('amplitude', <Parameter 'amplitude', value=75655.92801500537 +/- 765, bounds=[-inf:inf]>), ('center', <Parameter 'center', value=351.39064673527525 +/- 0.0109, bounds=[-inf:inf]>), ('sigma', <Parameter 'sigma', value=1.0626491837984142 +/- 0.0114, bounds=[0.0:inf]>), ('fwhm', <Parameter 'fwhm', value=2.502347550992182 +/- 0.0269, bounds=[-inf:inf], expr='2.3548200*sigma'>), ('height', <Parameter 'height', value=28402.92957554871 +/- 257, bounds=[-inf:inf], expr='0.3989423*amplitude/max(1e-15, sigma)'>), ('slope', <Parameter 'slope', value=-15.139188956477268 +/- 7.87, bounds=[-inf:inf]>), ('intercept', <Parameter 'intercept', value=6389.351841872048 +/- 2.77e+03, bounds=[-inf:inf]>)])

# %% [markdown]
# # Ajuste th

# %% [markdown]
# referencia

# %%
plt.plot(E,th_I)
fit=ajusteE(th_I,2590,2630)
fit.params
plt.plot(np.linspace(2590,2630,100),fit.eval(x=np.linspace(2590,2630,100)))
plt.xlim(2590,2630)
plt.ylim(0,12500)

print(f"I={I(fit.uvars['sigma']/recta.params['slope'],fit.uvars['height']):.1uS}")
fit.params
# Out:
# I=1.23(1)e+05
# Parameters([('amplitude', <Parameter 'amplitude', value=59263.44854021886 +/- 476, bounds=[-inf:inf]>), ('center', <Parameter 'center', value=2611.4153757371155 +/- 0.0174, bounds=[-inf:inf]>), ('sigma', <Parameter 'sigma', value=2.226736135875992 +/- 0.0185, bounds=[0.0:inf]>), ('fwhm', <Parameter 'fwhm', value=5.243562787483504 +/- 0.0435, bounds=[-inf:inf], expr='2.3548200*sigma'>), ('height', <Parameter 'height', value=10617.646197790553 +/- 72.9, bounds=[-inf:inf], expr='0.3989423*amplitude/max(1e-15, sigma)'>), ('slope', <Parameter 'slope', value=1.0092103689895537 +/- 1.61, bounds=[-inf:inf]>), ('intercept', <Parameter 'intercept', value=-2581.783743364017 +/- 4.19e+03, bounds=[-inf:inf]>)])

# %% [markdown]
# muestra

# %%
plt.plot(E,suelo_I)
fit=ajusteE(suelo_I,2590,2630)
fit.params
plt.plot(np.linspace(2590,2630,100),fit.eval(x=np.linspace(2590,2630,100)))
plt.xlim(2590,2630)
plt.ylim(0,300)

print(f"I={I(fit.uvars['sigma']/recta.params['slope'],fit.uvars['height']):.1uS}")
fit.params
# Out:
# I=1.51(3)e+03
# Parameters([('amplitude', <Parameter 'amplitude', value=724.3482232100255 +/- 12.6, bounds=[-inf:inf]>), ('center', <Parameter 'center', value=2611.383280377799 +/- 0.0215, bounds=[-inf:inf]>), ('sigma', <Parameter 'sigma', value=1.1641057771114545 +/- 0.0221, bounds=[0.0:inf]>), ('fwhm', <Parameter 'fwhm', value=2.7412595660575954 +/- 0.0521, bounds=[-inf:inf], expr='2.3548200*sigma'>), ('height', <Parameter 'height', value=248.23615847467264 +/- 4.01, bounds=[-inf:inf], expr='0.3989423*amplitude/max(1e-15, sigma)'>), ('slope', <Parameter 'slope', value=0.05521544020525653 +/- 0.0641, bounds=[-inf:inf]>), ('intercept', <Parameter 'intercept', value=-142.54086071328715 +/- 167, bounds=[-inf:inf]>)])

# %%
fig,ax=plt.subplots(1,2,figsize=(12,4))
fit=ajusteE(u_I,340,365)


ax[0].plot(E,1e-4*u_I,ds="steps-mid",label="RGU")
ax[0].plot(np.linspace(340,365,100),1e-4*fit.eval(x=np.linspace(340,365,100)))
ax[0].set_xlim(340,365)
ax[0].grid()
ax[0].set_ylabel("I$_\gamma$ ($10^4$cuentas / canal)", fontsize=11,family="serif")
ax[0].legend()
ax[0].set_xlabel("E (keV)", fontsize=11,family="serif")

fi2t=ajusteE(suelo_I,340,365)
ax[1].plot(E,1e-4*suelo_I,ds="steps-mid",label="DG-EG")
ax[1].plot(np.linspace(340,365,100),1e-4*fi2t.eval(x=np.linspace(340,365,100)))
ax[1].set_xlim(340,365)
ax[1].grid()
ax[1].set_ylabel("I$_\gamma$ ($10^4$cuentas / canal)", fontsize=11,family="serif")
ax[1].legend()
ax[1].set_xlabel("E (keV)", fontsize=11,family="serif")
# Out:
# Text(0.5, 0, 'E (keV)')

# %%
fig,ax=plt.subplots(1,2,figsize=(12,4))
fit=ajusteE(th_I,2590,2630)


ax[0].plot(E,1e-4*th_I,ds="steps-mid",label="RGThxha")
ax[0].plot(np.linspace(2590,2630,100),1e-4*fit.eval(x=np.linspace(2590,2630,100)))
ax[0].set_xlim(2590,2630)
ax[0].grid()
ax[0].set_ylabel("I$_\gamma$ ($10^4$cuentas / canal)", fontsize=11,family="serif")
ax[0].legend()
ax[0].set_xlabel("E (keV)", fontsize=11,family="serif")
ax[0].set_ylim(0,1.5)

fi2t=ajusteE(suelo_I,2590,2630)
ax[1].plot(E,1e-2*suelo_I,ds="steps-mid",label="DG-EG")
ax[1].plot(np.linspace(2590,2630,100),1e-2*fi2t.eval(x=np.linspace(2590,2630,100)))
ax[1].set_xlim(2590,2630)
ax[1].grid()
ax[1].set_ylabel("I$_\gamma$ ($10^2$cuentas / canal)", fontsize=11,family="serif")
ax[1].legend()
ax[1].set_xlabel("E (keV)", fontsize=11,family="serif")
ax[1].set_ylim(0,3)
# Out:
# (0.0, 3.0)

# %%
plt.plot(E,suelo_I)
plt.xlim(0,3000)
plt.vlines(352,10000,3000,color="r")

# %%
plt.plot(E,u_I)
plt.vlines(352,10000,3000,color="r")
plt.xlim(0,3000)
# Out:
# (0.0, 3000.0)

# %%
plt.plot(E,th_I)
plt.vlines(352,10000,3000,color="r")
